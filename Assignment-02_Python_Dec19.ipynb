# %% [markdown]
# ### Math Tutor Using Random, Arithmetic Operators, and OOP
#
# *Scenario:*
# Create a `MathTutor` class that generates random math questions using `random` and `math operators`.
#
# * Track correct and incorrect answers.
# * Provide a score at the end.
# * Handle invalid input using exception handling.
#
# > Concepts: Random, Math, Exception Handling, Classes

# %%
# Your Solution Here
import random


class MathTutor:

    def __init__(self):
        self.correct_answers = 0
        self.incorrect_answers = 0

    def generate_question(self):
        num1 = random.randint(1, 10)
        num2 = random.randint(1, 10)

        operator = random.choice(["+", "-", "*", "/"])

        if operator == "+":
            answer = num1 + num2

        elif operator == "-":
            answer = num1 - num2

        elif operator == "*":
            answer = num1 * num2

        else:
            # Avoid division by zero
            answer = round(num1 / num2, 2)

        return num1, num2, operator, answer

    def start_quiz(self, total_questions=5):

        for i in range(total_questions):

            num1, num2, operator, correct_answer = self.generate_question()

            try:
                user_answer = float(
                    input(f"Q{i+1}: {num1} {operator} {num2} = ")
                )

                if round(user_answer, 2) == round(correct_answer, 2):
                    print("Correct!\n")
                    self.correct_answers += 1
                else:
                    print(f"Wrong! Correct answer is {correct_answer}\n")
                    self.incorrect_answers += 1

            except ValueError:
                print("Invalid input! Please enter a number.\n")
                self.incorrect_answers += 1

    def show_score(self):
        print("===== SCORE =====")
        print(f"Correct Answers: {self.correct_answers}")
        print(f"Incorrect Answers: {self.incorrect_answers}")
        print(f"Final Score: {self.correct_answers}")


# Create object
tutor = MathTutor()

# Start quiz
tutor.start_quiz()

# Show final score
tutor.show_score()
# Out:
# Wrong! Correct answer is 4.0
#
# Correct!
#
# Correct!
#
# Wrong! Correct answer is 34
#
# Correct!
#
# ===== SCORE =====
# Correct Answers: 3
# Incorrect Answers: 2
# Final Score: 3

# %% [markdown]
# ### Multi-file Project Using Modules and Packages
#
# *Scenario:*
# You're building a small finance app.
#
# * Create a package `finance_tools` with modules: `tax.py` and `loan.py`.
# * Each module contains utility functions like `calculate_tax()` and `calculate_emi()`.
# * Import and use them in a main script that takes user input to do both.
#
# > Concepts: Packages, Modules, Importing, Separation of Concerns

# %%
# Your Solution Here

# %% [markdown]
# ### Exception Handling Scenario: Online Age-Restricted Service
#
# **Scenario:**
# You’re building a sign-up system for an online movie rental platform. Some movies are age-restricted (18+). You need to ensure proper validation and error handling during user registration.
#
# **Task:**
#
# 1. Create a custom exception class called `UnderageError` that inherits from `Exception`.
# 2. Write a function `register_user()` that:
#
#    * Takes a user’s `name` and `age` as input.
#    * Raises `UnderageError` if the user is under 18.
#    * Otherwise, prints a welcome message.
# 3. Wrap the function call in a `try` block and handle the exception.
# 4. Use `else` to confirm successful registration and `finally` to always print **“Thank you for using MovieTime!”** regardless of outcome.
#
# Also try to validate if the age input is numeric. Raise a `ValueError` if not, and handle it separately.

# %%
# Your Solution Here
# 1. Custom exception class
class UnderageError(Exception):
    pass


# 2. Function to register user
def register_user(name, age):
    # Validate if age is numeric
    if not str(age).isdigit():
        raise ValueError("Age must be a numeric value.")

    age = int(age)

    # Check age restriction
    if age < 18:
        raise UnderageError(f"{name} is under 18 and cannot register.")

    print(f"Welcome {name}! Registration successful.")


# 3. Try-except-else-finally block
try:
    user_name = input("Enter your name: ")
    user_age = input("Enter your age: ")

    register_user(user_name, user_age)

except UnderageError as ue:
    print("Underage Error:", ue)

except ValueError as ve:
    print("Value Error:", ve)

else:
    print("User registered successfully with full access.")

finally:
    print("Thank you for using MovieTime!")
# Out:
# Welcome supriya! Registration successful.
# User registered successfully with full access.
# Thank you for using MovieTime!

# %% [markdown]
# # Problem Statement
#
# We want to build an online shopping cart system that allows users to add products to their cart, calculate the total cost, apply discounts, and generate an invoice. The system should include the following functionalities:
#
# - Adding products to the cart
# - Removing products from the cart
# - Calculating the total cost
# - Applying discounts based on user type
# - Generating an invoice
#
# ### 1. Create the Product class
#
# We create a basic `Product` class with attributes for the product name and price.

# %%
# Your Solution Here
class Product:
    def __init__(self, name , price):
        self.name = name
        self.price = price

# %% [markdown]
# ### 2.  Implement the User class
#
# In this step, we create a `User` class with attributes for the user's name and whether they are a premium member.

# %%
# Your Solution Here
class User:
    def __init__(self, users_name,premium_member):
        self.users_name = users_name
        self.premium_member = premium_member

# %% [markdown]
# ### 3. Create the ShoppingCart class
#
# In this step, we create a `ShoppingCart` class with methods for adding and removing products from the cart, as well as calculating the total cost of the items in the cart.
#
# **Note**: Define `calculate_total_cost` method in the `ShoppingCart` class, that applies a `10%` discount to the total cost if you are `premium` User.

# %%
# Your Solution Here

class ShoppingCart(Product, User):

    def __init__(self, premium=False):
        self.cart = []
        self.premium = premium

    def add(self, product):
        self.cart.append(product)

    def remove(self, product):
        if product in self.cart:
            self.cart.remove(product)
        print("Product isn't in cart")    

    def calculate_total_cost(self):
        total_cost = sum(product.price for product in self.cart)

        if self.premium:
            total_cost = total_cost * 0.90  

        return total_cost

# %% [markdown]
# ### 4. Testing the functionality
#
# Now that we have implemented the necessary classes and methods, let's test our online shopping cart system:

# %%
# Your Solution Here
# Create products
product1 = Product("Laptop", 1000)
product2 = Product("Mouse", 50)
product3 = Product("Keyboard", 100)

# Create shopping cart for a premium user
cart = ShoppingCart(premium=True)

# Add products
cart.add(product1)
cart.add(product2)
cart.add(product3)

# Remove one product
cart.remove(product2)

# Calculate total cost
print("Total Cost:", cart.calculate_total_cost())
# Out:
# Total Cost: 990.0

# %% [markdown]
# ### 5. Generating Invoice for a given cart

# %%
# 5. Generating Invoice for a given cart

class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price


class User:
    def __init__(self, username, premium=False):
        self.username = username
        self.premium = premium


class ShoppingCart:

    def __init__(self, user):
        self.user = user
        self.cart = []

    def add(self, product):
        self.cart.append(product)

    def remove(self, product):
        if product in self.cart:
            self.cart.remove(product)

    def calculate_total_cost(self):
        total_cost = sum(product.price for product in self.cart)

        if self.user.premium:
            total_cost *= 0.90   # 10% discount

        return total_cost

    def generate_invoice(self):
        print("\n===== INVOICE =====")
        print(f"Customer: {self.user.username}")
        print("-------------------")

        for product in self.cart:
            print(f"{product.name}: ${product.price}")

        print("-------------------")
        print(f"Total Amount: ${self.calculate_total_cost()}")
        print("===================")


# Create products
product1 = Product("Laptop", 1000)
product2 = Product("Mouse", 50)
product3 = Product("Keyboard", 100)

# Create user
user1 = User("John", premium=True)

# Create shopping cart
cart = ShoppingCart(user1)

# Add products to cart
cart.add(product1)
cart.add(product2)
cart.add(product3)

# Generate invoice
cart.generate_invoice()
# Out:
# ===== INVOICE =====
# Customer: John
# -------------------
# Laptop: $1000
# Mouse: $50
# Keyboard: $100
# -------------------
# Total Amount: $1035.0
# ===================
